# %%
command = """
/home/shibal/anaconda3/envs/jasa/bin/python -u /home/shibal/Additive-Models-with-Structured-Interactions/SparseAMsWithInteractions/src/AMsWithInteractionsStrongHierarchy/AMsWithInteractionsStrongHierarchy.py --load_directory '/pool001/shibal/Census-Data' --seed 0 --relative_penalty 1.0 --version 5 --eval_criteria 'mse' --logging |& tee -a '/pool001/shibal/aoas_results/AMsWithInteractionsStrongHierarchy/v5/r1.0/seed0/output.txt'
"""

# %%
# !{command}
# Out:
# 3.6.12 | packaged by conda-forge | (default, Dec  9 2020, 00:36:02)
# [GCC 9.3.0] linux /home/shibal/anaconda3/envs/jasa/bin/python
# Number of training samples: 57598
# Number of validation samples: 7199
# Number of test samples: 7199
# Number of covariates: 295
# Number of interaction effects to consider: 10
# Generating bspline basis for main effects...
# ...
#
# Bspline basis for main effects generated.
# Generating bspline basis for interaction effects...
# ...
#
# Bspline basis for interaction effects generated
# lambda_1,lambda_2,tau,train,val,Obj,Main-Effects,Interaction-Effects
# ...
# Using license file /home/software/sloan/gurobi/gurobi.lic
# Set parameter TokenServer to value engaging-license-001
# Changed value of parameter LogFile to /pool001/shibal/aoas_results/AMsWithInteractionsStrongHierarchy/v5/r1.0/seed0/gurobi.log
#    Prev:   Default:
# Gurobi Optimizer version 9.0.1 build v9.0.1rc0 (linux64)
# Optimize a model with 20 rows, 3475 columns and 40 nonzeros
# ...
