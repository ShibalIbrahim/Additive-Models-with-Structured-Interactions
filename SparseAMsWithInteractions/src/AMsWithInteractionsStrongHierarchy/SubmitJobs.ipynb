# %%
import numpy as np
import pandas as pd
import os
import shutil
from subprocess import Popen, PIPE
from IPython.display import clear_output
import time

# %%
PYPATH = '/home/shibal/anaconda3/envs/jasa/bin/python'
FILEPATH = '/home/shibal/Additive-Models-with-Structured-Interactions/SparseAMsWithInteractions/src/AMsWithInteractionsStrongHierarchy/AMsWithInteractionsStrongHierarchy-Synthetic-CV.py'
PATH = "/pool001/shibal/results-synthetic"

version = 13
n = 400
r = 1.0

# %%
def make_bash_file(seed, version, n, r):
    bash_folder_path = f"{PATH}/bashes/v{version}_n{n}_r{r}"
    bash_file_path = os.path.join(bash_folder_path, "seed{}.sh".format(seed))
    log_path = f"{PATH}/logs/v{version}_n{n}_r{r}/seed{seed}"
    os.makedirs(bash_folder_path,exist_ok=True)
    os.makedirs(log_path,exist_ok=True)
    with open(bash_file_path,"w") as f:
        f.write("#!/bin/bash\n")
        f.write("#SBATCH --cpus-per-task=4\n")
        f.write("#SBATCH --time=4-00:00\n")
        f.write("#SBATCH --mem=16G\n")
        f.write("#SBATCH -p sched_mit_sloan_batch\n")        
        f.write("#SBATCH --mail-type=FAIL\n")
        f.write("#SBATCH --mail-user=shibal@mit.edu\n")
        f.write(f"#SBATCH -o {log_path}/seed{seed}_%j.out\n")
        f.write(f"#SBATCH -e {log_path}/_seed{seed}_%j.err\n\n")
        f.write("module load sloan/python/modules/python-3.6/gurobipy/9.0.1\n\n")
        f.write(f"{PYPATH} -u {FILEPATH}  --seed {seed} --train_size {n} --version {version} --r {r} |& tee -a {log_path}/output.txt") 
    return bash_file_path

# %%
bash_files = []
seeds = np.arange(95,100)
for seed in seeds:
    bash_files.append(make_bash_file(seed, version, n, r))

# %%
torun = seeds
# torun = range(1,6)
submitted = []
print(len(torun))
# Out:
# 100

# %%
exit_code = 1
for i, seed in enumerate(seeds):
    if i % 100 == 0:
        clear_output(wait=True)
    print(i)
    sh = make_bash_file(seed, version, n, r)
    while True:
        process = Popen(["sbatch",sh], stdout=PIPE)
        (output, err) = process.communicate()
        exit_code = process.wait()
        print(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())),output,err)
        if exit_code == 0:
            print(sh,"submitted!")
            tmp_id = str(output)[-11:-3]
            print("job id:", tmp_id)
            submitted.append(tmp_id)
            break
        time.sleep(10000)
# Out:
# 0
# 2022-10-28 07:26:53 b'Submitted batch job 45144293\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed0.sh submitted!
# job id: 45144293
# 1
# 2022-10-28 07:26:53 b'Submitted batch job 45144295\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed1.sh submitted!
# job id: 45144295
# 2
# 2022-10-28 07:26:54 b'Submitted batch job 45144296\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed2.sh submitted!
# job id: 45144296
# 3
# 2022-10-28 07:26:54 b'Submitted batch job 45144297\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed3.sh submitted!
# job id: 45144297
# 4
# 2022-10-28 07:26:55 b'Submitted batch job 45144298\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed4.sh submitted!
# job id: 45144298
# 5
# 2022-10-28 07:26:55 b'Submitted batch job 45144299\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed5.sh submitted!
# job id: 45144299
# 6
# 2022-10-28 07:26:55 b'Submitted batch job 45144300\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed6.sh submitted!
# job id: 45144300
# 7
# 2022-10-28 07:26:56 b'Submitted batch job 45144301\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed7.sh submitted!
# job id: 45144301
# 8
# 2022-10-28 07:26:56 b'Submitted batch job 45144302\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed8.sh submitted!
# job id: 45144302
# 9
# 2022-10-28 07:26:56 b'Submitted batch job 45144303\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed9.sh submitted!
# job id: 45144303
# 10
# 2022-10-28 07:26:57 b'Submitted batch job 45144304\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed10.sh submitted!
# job id: 45144304
# 11
# 2022-10-28 07:26:57 b'Submitted batch job 45144305\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed11.sh submitted!
# job id: 45144305
# 12
# 2022-10-28 07:26:57 b'Submitted batch job 45144306\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed12.sh submitted!
# job id: 45144306
# 13
# 2022-10-28 07:26:57 b'Submitted batch job 45144307\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed13.sh submitted!
# job id: 45144307
# 14
# 2022-10-28 07:26:58 b'Submitted batch job 45144308\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed14.sh submitted!
# job id: 45144308
# 15
# 2022-10-28 07:26:58 b'Submitted batch job 45144309\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed15.sh submitted!
# job id: 45144309
# 16
# 2022-10-28 07:26:58 b'Submitted batch job 45144310\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed16.sh submitted!
# job id: 45144310
# 17
# 2022-10-28 07:26:59 b'Submitted batch job 45144311\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed17.sh submitted!
# job id: 45144311
# 18
# 2022-10-28 07:26:59 b'Submitted batch job 45144312\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed18.sh submitted!
# job id: 45144312
# 19
# 2022-10-28 07:26:59 b'Submitted batch job 45144313\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed19.sh submitted!
# job id: 45144313
# 20
# 2022-10-28 07:27:00 b'Submitted batch job 45144314\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed20.sh submitted!
# job id: 45144314
# 21
# 2022-10-28 07:27:00 b'Submitted batch job 45144315\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed21.sh submitted!
# job id: 45144315
# 22
# 2022-10-28 07:27:00 b'Submitted batch job 45144316\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed22.sh submitted!
# job id: 45144316
# 23
# 2022-10-28 07:27:01 b'Submitted batch job 45144317\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed23.sh submitted!
# job id: 45144317
# 24
# 2022-10-28 07:27:01 b'Submitted batch job 45144318\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed24.sh submitted!
# job id: 45144318
# 25
# 2022-10-28 07:27:01 b'Submitted batch job 45144319\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed25.sh submitted!
# job id: 45144319
# 26
# 2022-10-28 07:27:02 b'Submitted batch job 45144320\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed26.sh submitted!
# job id: 45144320
# 27
# 2022-10-28 07:27:02 b'Submitted batch job 45144321\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed27.sh submitted!
# job id: 45144321
# 28
# 2022-10-28 07:27:02 b'Submitted batch job 45144322\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed28.sh submitted!
# job id: 45144322
# 29
# 2022-10-28 07:27:02 b'Submitted batch job 45144323\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed29.sh submitted!
# job id: 45144323
# 30
# 2022-10-28 07:27:03 b'Submitted batch job 45144324\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed30.sh submitted!
# job id: 45144324
# 31
# 2022-10-28 07:27:03 b'Submitted batch job 45144325\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed31.sh submitted!
# job id: 45144325
# 32
# 2022-10-28 07:27:03 b'Submitted batch job 45144326\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed32.sh submitted!
# job id: 45144326
# 33
# 2022-10-28 07:27:03 b'Submitted batch job 45144327\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed33.sh submitted!
# job id: 45144327
# 34
# 2022-10-28 07:27:03 b'Submitted batch job 45144328\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed34.sh submitted!
# job id: 45144328
# 35
# 2022-10-28 07:27:04 b'Submitted batch job 45144329\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed35.sh submitted!
# job id: 45144329
# 36
# 2022-10-28 07:27:04 b'Submitted batch job 45144330\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed36.sh submitted!
# job id: 45144330
# 37
# 2022-10-28 07:27:04 b'Submitted batch job 45144331\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed37.sh submitted!
# job id: 45144331
# 38
# 2022-10-28 07:27:05 b'Submitted batch job 45144332\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed38.sh submitted!
# job id: 45144332
# 39
# 2022-10-28 07:27:05 b'Submitted batch job 45144333\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed39.sh submitted!
# job id: 45144333
# 40
# 2022-10-28 07:27:05 b'Submitted batch job 45144334\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed40.sh submitted!
# job id: 45144334
# 41
# 2022-10-28 07:27:05 b'Submitted batch job 45144335\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed41.sh submitted!
# job id: 45144335
# 42
# 2022-10-28 07:27:06 b'Submitted batch job 45144336\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed42.sh submitted!
# job id: 45144336
# 43
# 2022-10-28 07:27:06 b'Submitted batch job 45144337\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed43.sh submitted!
# job id: 45144337
# 44
# 2022-10-28 07:27:06 b'Submitted batch job 45144338\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed44.sh submitted!
# job id: 45144338
# 45
# 2022-10-28 07:27:06 b'Submitted batch job 45144339\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed45.sh submitted!
# job id: 45144339
# 46
# 2022-10-28 07:27:07 b'Submitted batch job 45144340\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed46.sh submitted!
# job id: 45144340
# 47
# 2022-10-28 07:27:07 b'Submitted batch job 45144341\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed47.sh submitted!
# job id: 45144341
# 48
# 2022-10-28 07:27:07 b'Submitted batch job 45144342\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed48.sh submitted!
# job id: 45144342
# 49
# 2022-10-28 07:27:07 b'Submitted batch job 45144343\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed49.sh submitted!
# job id: 45144343
# 50
# 2022-10-28 07:27:08 b'Submitted batch job 45144344\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed50.sh submitted!
# job id: 45144344
# 51
# 2022-10-28 07:27:08 b'Submitted batch job 45144345\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed51.sh submitted!
# job id: 45144345
# 52
# 2022-10-28 07:27:08 b'Submitted batch job 45144346\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed52.sh submitted!
# job id: 45144346
# 53
# 2022-10-28 07:27:08 b'Submitted batch job 45144347\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed53.sh submitted!
# job id: 45144347
# 54
# 2022-10-28 07:27:09 b'Submitted batch job 45144348\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed54.sh submitted!
# job id: 45144348
# 55
# 2022-10-28 07:27:09 b'Submitted batch job 45144349\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed55.sh submitted!
# job id: 45144349
# 56
# 2022-10-28 07:27:09 b'Submitted batch job 45144350\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed56.sh submitted!
# job id: 45144350
# 57
# 2022-10-28 07:27:09 b'Submitted batch job 45144351\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed57.sh submitted!
# job id: 45144351
# 58
# 2022-10-28 07:27:10 b'Submitted batch job 45144352\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed58.sh submitted!
# job id: 45144352
# 59
# 2022-10-28 07:27:10 b'Submitted batch job 45144353\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed59.sh submitted!
# job id: 45144353
# 60
# 2022-10-28 07:27:11 b'Submitted batch job 45144354\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed60.sh submitted!
# job id: 45144354
# 61
# 2022-10-28 07:27:11 b'Submitted batch job 45144355\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed61.sh submitted!
# job id: 45144355
# 62
# 2022-10-28 07:27:11 b'Submitted batch job 45144356\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed62.sh submitted!
# job id: 45144356
# 63
# 2022-10-28 07:27:11 b'Submitted batch job 45144357\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed63.sh submitted!
# job id: 45144357
# 64
# 2022-10-28 07:27:12 b'Submitted batch job 45144358\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed64.sh submitted!
# job id: 45144358
# 65
# 2022-10-28 07:27:12 b'Submitted batch job 45144359\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed65.sh submitted!
# job id: 45144359
# 66
# 2022-10-28 07:27:12 b'Submitted batch job 45144360\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed66.sh submitted!
# job id: 45144360
# 67
# 2022-10-28 07:27:12 b'Submitted batch job 45144361\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed67.sh submitted!
# job id: 45144361
# 68
# 2022-10-28 07:27:13 b'Submitted batch job 45144362\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed68.sh submitted!
# job id: 45144362
# 69
# 2022-10-28 07:27:13 b'Submitted batch job 45144363\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed69.sh submitted!
# job id: 45144363
# 70
# 2022-10-28 07:27:13 b'Submitted batch job 45144364\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed70.sh submitted!
# job id: 45144364
# 71
# 2022-10-28 07:27:13 b'Submitted batch job 45144365\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed71.sh submitted!
# job id: 45144365
# 72
# 2022-10-28 07:27:14 b'Submitted batch job 45144366\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed72.sh submitted!
# job id: 45144366
# 73
# 2022-10-28 07:27:14 b'Submitted batch job 45144367\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed73.sh submitted!
# job id: 45144367
# 74
# 2022-10-28 07:27:14 b'Submitted batch job 45144368\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed74.sh submitted!
# job id: 45144368
# 75
# 2022-10-28 07:27:14 b'Submitted batch job 45144369\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed75.sh submitted!
# job id: 45144369
# 76
# 2022-10-28 07:27:15 b'Submitted batch job 45144370\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed76.sh submitted!
# job id: 45144370
# 77
# 2022-10-28 07:27:15 b'Submitted batch job 45144371\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed77.sh submitted!
# job id: 45144371
# 78
# 2022-10-28 07:27:15 b'Submitted batch job 45144372\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed78.sh submitted!
# job id: 45144372
# 79
# 2022-10-28 07:27:16 b'Submitted batch job 45144373\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed79.sh submitted!
# job id: 45144373
# 80
# 2022-10-28 07:27:16 b'Submitted batch job 45144374\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed80.sh submitted!
# job id: 45144374
# 81
# 2022-10-28 07:27:16 b'Submitted batch job 45144375\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed81.sh submitted!
# job id: 45144375
# 82
# 2022-10-28 07:27:16 b'Submitted batch job 45144376\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed82.sh submitted!
# job id: 45144376
# 83
# 2022-10-28 07:27:16 b'Submitted batch job 45144377\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed83.sh submitted!
# job id: 45144377
# 84
# 2022-10-28 07:27:17 b'Submitted batch job 45144378\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed84.sh submitted!
# job id: 45144378
# 85
# 2022-10-28 07:27:17 b'Submitted batch job 45144379\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed85.sh submitted!
# job id: 45144379
# 86
# 2022-10-28 07:27:17 b'Submitted batch job 45144380\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed86.sh submitted!
# job id: 45144380
# 87
# 2022-10-28 07:27:18 b'Submitted batch job 45144381\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed87.sh submitted!
# job id: 45144381
# 88
# 2022-10-28 07:27:18 b'Submitted batch job 45144382\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed88.sh submitted!
# job id: 45144382
# 89
# 2022-10-28 07:27:18 b'Submitted batch job 45144383\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed89.sh submitted!
# job id: 45144383
# 90
# 2022-10-28 07:27:19 b'Submitted batch job 45144384\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed90.sh submitted!
# job id: 45144384
# 91
# 2022-10-28 07:27:19 b'Submitted batch job 45144385\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed91.sh submitted!
# job id: 45144385
# 92
# 2022-10-28 07:27:19 b'Submitted batch job 45144386\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed92.sh submitted!
# job id: 45144386
# 93
# 2022-10-28 07:27:20 b'Submitted batch job 45144387\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed93.sh submitted!
# job id: 45144387
# 94
# 2022-10-28 07:27:20 b'Submitted batch job 45144388\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n400_r1.0/seed94.sh submitted!
# job id: 45144388
# 95
# 2022-10-28 07:27:20 b'' None
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-243-ba51ac46df20>", line 18, in <module>
#     time.sleep(10000)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '<ipython-input-243-ba51ac46df20>'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/shibal/anaconda3/envs/jasa/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-243-ba51ac46df20> in <module>
#      17             break
# ---> 18         time.sleep(10000)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# ~/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# ~/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# ~/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/anaconda3/envs/jasa/lib/python3.6/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
from subprocess import Popen, PIPE

# %%
for job in range(45069627, 45069643):
    process = Popen(['scancel',str(job)], stdout=PIPE)
    (output, err) = process.communicate()
    exit_code = process.wait()
    if exit_code ==0:
        print(job, "deleted!")
# Out:
# 45069627 deleted!
# 45069628 deleted!
# 45069629 deleted!
# 45069630 deleted!
# 45069631 deleted!
# 45069632 deleted!
# 45069633 deleted!
# 45069634 deleted!
# 45069635 deleted!
# 45069636 deleted!
# 45069637 deleted!
# 45069638 deleted!
# 45069639 deleted!
# 45069640 deleted!
# 45069641 deleted!
# 45069642 deleted!

# %%
for seed in range(100):
    command = f"""rm -r /pool001/shibal/results-synthetic/N_train_100/seed{seed}/AMsWithInteractionsStrongHierarchy/v12/r1.0"""
    print(command)
    # !{command}
# Out:
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed0/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed1/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed2/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed3/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed4/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed5/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed6/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed7/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed8/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed9/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed10/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed11/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed12/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed13/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed14/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed15/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed16/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed17/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed18/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed19/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed20/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed21/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed22/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed23/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed24/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed25/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed26/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed27/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed28/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed29/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed30/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed31/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed32/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed33/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed34/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed35/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed36/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed37/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed38/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed39/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed40/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed41/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed42/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed43/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed44/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed45/AMsWithInteractionsStrongHierarchy/v12/r1.0
# ^C
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed46/AMsWithInteractionsStrongHierarchy/v12/r1.0
# ^C
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed47/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed48/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed49/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed50/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed51/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed52/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed53/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed54/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed55/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed56/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed57/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed58/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed59/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed60/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed61/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed62/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed63/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed64/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed65/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed66/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed67/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed68/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed69/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed70/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed71/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed72/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed73/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed74/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed75/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed76/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed77/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed78/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed79/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed80/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed81/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed82/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed83/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed84/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed85/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed86/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed87/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed88/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed89/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed90/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed91/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed92/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed93/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed94/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed95/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed96/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed97/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed98/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed99/AMsWithInteractionsStrongHierarchy/v12/r1.0

# %%
import numpy as np

# %%
MISE = []
mains = []
interactions = []
fprs_main = []
fnrs_main = []
f1s_main = []
fprs_interaction = []
fnrs_interaction = []
f1s_interaction = []


for seed in np.arange(100):
    filename = '/pool001/shibal/results-synthetic/N_train_400/seed{}/AMsWithInteractionsStrongHierarchy/v12/r1.5'.format(seed)
    
    try:
        with open(filename+'/Results-HS.txt') as file:
            lines = file.readlines()
            mise = float([line for line in lines if "True" in line][0].split(" ")[-1].split("\n")[0])
            MISE.append(mise)
            fpr_main = float([line for line in lines if "FPR (main)" in line][0].split(" ")[-1].split("\n")[0])
            fprs_main.append(fpr_main)
            fnr_main = float([line for line in lines if "FNR (main)" in line][0].split(" ")[-1].split("\n")[0])
            fnrs_main.append(fnr_main)
            f1_main = float([line for line in lines if "F1 (main)" in line][0].split(" ")[-1].split("\n")[0])
            f1s_main.append(f1_main)
            fpr_interaction = float([line for line in lines if "FPR (interactions)" in line][0].split(" ")[-1].split("\n")[0])
            fprs_interaction.append(fpr_interaction)
            fnr_interaction = float([line for line in lines if "FNR (interactions)" in line][0].split(" ")[-1].split("\n")[0])
            fnrs_interaction.append(fnr_interaction)
            f1_interaction = float([line for line in lines if "F1 (interactions)" in line][0].split(" ")[-1].split("\n")[0])
            f1s_interaction.append(f1_interaction)
            print("Seed: ", seed, " mise:", mise)
            
        with open(filename+'/support_set.npy', 'rb') as f:
            main_set = np.load(f)
            interaction_set = np.load(f)
            mains.append(main_set)
            interactions.append(interaction_set)
    except:
        pass

# %%
len(MISE)

# %%
np.median(MISE)
# Out:
# /home/shibal/anaconda3/envs/jasa/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/shibal/anaconda3/envs/jasa/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan

# %%
print("MISE:", np.mean(MISE), "std-err:", np.std(MISE)/np.sqrt(len(MISE)))
print("FPR (main):", np.mean(fprs_main), "std-err:", np.std(fprs_main)/np.sqrt(len(fprs_main)))
print("FNR (main):", np.mean(fnrs_main), "std-err:", np.std(fnrs_main)/np.sqrt(len(fnrs_main)))
print("F1 (main):", np.mean(f1s_main), "std-err:", np.std(f1s_main)/np.sqrt(len(f1s_main)))
print("FPR (interactions):", np.mean(fprs_interaction), "std-err:", np.std(fprs_interaction)/np.sqrt(len(fprs_interaction)))
print("FNR (interactions):", np.mean(fnrs_interaction), "std-err:", np.std(fnrs_interaction)/np.sqrt(len(fnrs_interaction)))
print("F1 (interactions):", np.mean(f1s_interaction), "std-err:", np.std(f1s_interaction)/np.sqrt(len(f1s_interaction)))
# Out:
# MISE: 0.050922325140178935 std-err: 0.0061614350605426445
# FPR (main): 0.006734006734006734 std-err: 0.00528050473222291
# FNR (main): 0.020202020202020204 std-err: 0.007723118706483095
# F1 (main): 0.9840978325826811 std-err: 0.005488585525612171
# FPR (interactions): 0.001924001924001925 std-err: 0.0009423662235774552
# FNR (interactions): 0.15824915824915828 std-err: 0.020393833688234244
# F1 (interactions): 0.8888648388648388 std-err: 0.014151465290720134

# %%
np.unique(np.concatenate(mains).ravel(), return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([98, 98, 98, 98,  1]))

# %%
interactions = [inter for inter in interactions if len(inter)>0]
np.unique(np.concatenate(interactions, axis=0), return_counts=True, axis=0)
# Out:
# (array([[0, 1],
#         [0, 2],
#         [0, 3],
#         [0, 4],
#         [1, 3],
#         [2, 3],
#         [2, 4]]),
#  array([98, 98,  3,  1,  3, 94,  1]))
