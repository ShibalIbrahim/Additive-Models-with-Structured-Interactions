# %%
import numpy as np
import pandas as pd
import os
import shutil
from subprocess import Popen, PIPE
from IPython.display import clear_output
import time

# %%
PYPATH = '/home/shibal/anaconda3/envs/jasa/bin/python'
FILEPATH = '/home/shibal/Additive-Models-with-Structured-Interactions/SparseAMsWithInteractions/src/AMsWithInteractionsStrongHierarchy/AMsWithInteractionsStrongHierarchy-Synthetic-CV.py'
PATH = "/pool001/shibal/results-synthetic"

version = 13
# n = 100
r = 1.5
dist = 'skewed'

# %%
def make_bash_file(seed, version, dist, r):
    bash_folder_path = f"{PATH}/bashes/{dist}/v{version}_r{r}"
    bash_file_path = os.path.join(bash_folder_path, "seed{}.sh".format(seed))
    log_path = f"{PATH}/logs/{dist}/v{version}_r{r}/seed{seed}"
    os.makedirs(bash_folder_path,exist_ok=True)
    os.makedirs(log_path,exist_ok=True)
    with open(bash_file_path,"w") as f:
        f.write("#!/bin/bash\n")
        f.write("#SBATCH --cpus-per-task=4\n")
        f.write("#SBATCH --time=4-00:00\n")
        f.write("#SBATCH --mem=16G\n")
        f.write("#SBATCH -p sched_mit_sloan_batch\n")        
        f.write("#SBATCH --mail-type=FAIL\n")
        f.write("#SBATCH --mail-user=shibal@mit.edu\n")
        f.write(f"#SBATCH -o {log_path}/seed{seed}_%j.out\n")
        f.write(f"#SBATCH -e {log_path}/_seed{seed}_%j.err\n\n")
        f.write("module load sloan/python/modules/python-3.6/gurobipy/9.0.1\n\n")
        f.write(f"{PYPATH} -u {FILEPATH} --dist {dist} --seed {seed} --train_size {100} --version {version} --r {r} |& tee -a {log_path}/output.txt") 
        f.write(f"{PYPATH} -u {FILEPATH} --dist {dist} --seed {seed} --train_size {200} --version {version} --r {r} |& tee -a {log_path}/output.txt") 
        f.write(f"{PYPATH} -u {FILEPATH} --dist {dist} --seed {seed} --train_size {400} --version {version} --r {r} |& tee -a {log_path}/output.txt") 
    return bash_file_path

# %%
bash_files = []
seeds = np.arange(100)
for seed in seeds:
    bash_files.append(make_bash_file(seed, version, n, r))

# %%
torun = seeds
# torun = range(1,6)
submitted = []
print(len(torun))
# Out:
# 100

# %%
exit_code = 1
for i, seed in enumerate(seeds):
    if i % 100 == 0:
        clear_output(wait=True)
    print(i)
    sh = make_bash_file(seed, version, n, r)
    while True:
        process = Popen(["sbatch",sh], stdout=PIPE)
        (output, err) = process.communicate()
        exit_code = process.wait()
        print(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())),output,err)
        if exit_code == 0:
            print(sh,"submitted!")
            tmp_id = str(output)[-11:-3]
            print("job id:", tmp_id)
            submitted.append(tmp_id)
            break
        time.sleep(10000)
# Out:
# 0
# 2022-10-29 08:07:53 b'Submitted batch job 45221349\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed0.sh submitted!
# job id: 45221349
# 1
# 2022-10-29 08:07:53 b'Submitted batch job 45221350\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed1.sh submitted!
# job id: 45221350
# 2
# 2022-10-29 08:07:53 b'Submitted batch job 45221351\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed2.sh submitted!
# job id: 45221351
# 3
# 2022-10-29 08:07:53 b'Submitted batch job 45221352\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed3.sh submitted!
# job id: 45221352
# 4
# 2022-10-29 08:07:54 b'Submitted batch job 45221353\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed4.sh submitted!
# job id: 45221353
# 5
# 2022-10-29 08:07:54 b'Submitted batch job 45221354\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed5.sh submitted!
# job id: 45221354
# 6
# 2022-10-29 08:07:54 b'Submitted batch job 45221355\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed6.sh submitted!
# job id: 45221355
# 7
# 2022-10-29 08:07:55 b'Submitted batch job 45221356\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed7.sh submitted!
# job id: 45221356
# 8
# 2022-10-29 08:07:55 b'Submitted batch job 45221357\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed8.sh submitted!
# job id: 45221357
# 9
# 2022-10-29 08:07:55 b'Submitted batch job 45221358\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed9.sh submitted!
# job id: 45221358
# 10
# 2022-10-29 08:07:55 b'Submitted batch job 45221359\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed10.sh submitted!
# job id: 45221359
# 11
# 2022-10-29 08:07:56 b'Submitted batch job 45221360\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed11.sh submitted!
# job id: 45221360
# 12
# 2022-10-29 08:07:56 b'Submitted batch job 45221361\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed12.sh submitted!
# job id: 45221361
# 13
# 2022-10-29 08:07:56 b'Submitted batch job 45221362\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed13.sh submitted!
# job id: 45221362
# 14
# 2022-10-29 08:07:57 b'Submitted batch job 45221363\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed14.sh submitted!
# job id: 45221363
# 15
# 2022-10-29 08:07:57 b'Submitted batch job 45221364\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed15.sh submitted!
# job id: 45221364
# 16
# 2022-10-29 08:07:57 b'Submitted batch job 45221365\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed16.sh submitted!
# job id: 45221365
# 17
# 2022-10-29 08:07:58 b'Submitted batch job 45221366\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed17.sh submitted!
# job id: 45221366
# 18
# 2022-10-29 08:07:58 b'Submitted batch job 45221367\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed18.sh submitted!
# job id: 45221367
# 19
# 2022-10-29 08:07:58 b'Submitted batch job 45221368\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed19.sh submitted!
# job id: 45221368
# 20
# 2022-10-29 08:07:59 b'Submitted batch job 45221369\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed20.sh submitted!
# job id: 45221369
# 21
# 2022-10-29 08:07:59 b'Submitted batch job 45221370\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed21.sh submitted!
# job id: 45221370
# 22
# 2022-10-29 08:07:59 b'Submitted batch job 45221371\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed22.sh submitted!
# job id: 45221371
# 23
# 2022-10-29 08:07:59 b'Submitted batch job 45221372\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed23.sh submitted!
# job id: 45221372
# 24
# 2022-10-29 08:07:59 b'Submitted batch job 45221373\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed24.sh submitted!
# job id: 45221373
# 25
# 2022-10-29 08:08:00 b'Submitted batch job 45221374\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed25.sh submitted!
# job id: 45221374
# 26
# 2022-10-29 08:08:00 b'Submitted batch job 45221375\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed26.sh submitted!
# job id: 45221375
# 27
# 2022-10-29 08:08:00 b'Submitted batch job 45221376\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed27.sh submitted!
# job id: 45221376
# 28
# 2022-10-29 08:08:01 b'Submitted batch job 45221377\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed28.sh submitted!
# job id: 45221377
# 29
# 2022-10-29 08:08:01 b'Submitted batch job 45221378\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed29.sh submitted!
# job id: 45221378
# 30
# 2022-10-29 08:08:01 b'Submitted batch job 45221379\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed30.sh submitted!
# job id: 45221379
# 31
# 2022-10-29 08:08:02 b'Submitted batch job 45221380\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed31.sh submitted!
# job id: 45221380
# 32
# 2022-10-29 08:08:02 b'Submitted batch job 45221381\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed32.sh submitted!
# job id: 45221381
# 33
# 2022-10-29 08:08:02 b'Submitted batch job 45221382\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed33.sh submitted!
# job id: 45221382
# 34
# 2022-10-29 08:08:02 b'Submitted batch job 45221383\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed34.sh submitted!
# job id: 45221383
# 35
# 2022-10-29 08:08:03 b'Submitted batch job 45221384\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed35.sh submitted!
# job id: 45221384
# 36
# 2022-10-29 08:08:03 b'Submitted batch job 45221385\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed36.sh submitted!
# job id: 45221385
# 37
# 2022-10-29 08:08:03 b'Submitted batch job 45221386\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed37.sh submitted!
# job id: 45221386
# 38
# 2022-10-29 08:08:03 b'Submitted batch job 45221387\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed38.sh submitted!
# job id: 45221387
# 39
# 2022-10-29 08:08:04 b'Submitted batch job 45221388\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed39.sh submitted!
# job id: 45221388
# 40
# 2022-10-29 08:08:04 b'Submitted batch job 45221389\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed40.sh submitted!
# job id: 45221389
# 41
# 2022-10-29 08:08:04 b'Submitted batch job 45221390\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed41.sh submitted!
# job id: 45221390
# 42
# 2022-10-29 08:08:04 b'Submitted batch job 45221391\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed42.sh submitted!
# job id: 45221391
# 43
# 2022-10-29 08:08:05 b'Submitted batch job 45221392\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed43.sh submitted!
# job id: 45221392
# 44
# 2022-10-29 08:08:05 b'Submitted batch job 45221393\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed44.sh submitted!
# job id: 45221393
# 45
# 2022-10-29 08:08:05 b'Submitted batch job 45221394\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed45.sh submitted!
# job id: 45221394
# 46
# 2022-10-29 08:08:05 b'Submitted batch job 45221395\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed46.sh submitted!
# job id: 45221395
# 47
# 2022-10-29 08:08:05 b'Submitted batch job 45221396\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed47.sh submitted!
# job id: 45221396
# 48
# 2022-10-29 08:08:06 b'Submitted batch job 45221397\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed48.sh submitted!
# job id: 45221397
# 49
# 2022-10-29 08:08:06 b'Submitted batch job 45221398\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed49.sh submitted!
# job id: 45221398
# 50
# 2022-10-29 08:08:06 b'Submitted batch job 45221399\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed50.sh submitted!
# job id: 45221399
# 51
# 2022-10-29 08:08:06 b'Submitted batch job 45221400\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed51.sh submitted!
# job id: 45221400
# 52
# 2022-10-29 08:08:07 b'Submitted batch job 45221401\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed52.sh submitted!
# job id: 45221401
# 53
# 2022-10-29 08:08:07 b'Submitted batch job 45221402\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed53.sh submitted!
# job id: 45221402
# 54
# 2022-10-29 08:08:07 b'Submitted batch job 45221403\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed54.sh submitted!
# job id: 45221403
# 55
# 2022-10-29 08:08:07 b'Submitted batch job 45221404\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed55.sh submitted!
# job id: 45221404
# 56
# 2022-10-29 08:08:08 b'Submitted batch job 45221405\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed56.sh submitted!
# job id: 45221405
# 57
# 2022-10-29 08:08:08 b'Submitted batch job 45221406\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed57.sh submitted!
# job id: 45221406
# 58
# 2022-10-29 08:08:09 b'Submitted batch job 45221407\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed58.sh submitted!
# job id: 45221407
# 59
# 2022-10-29 08:08:09 b'Submitted batch job 45221408\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed59.sh submitted!
# job id: 45221408
# 60
# 2022-10-29 08:08:09 b'Submitted batch job 45221409\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed60.sh submitted!
# job id: 45221409
# 61
# 2022-10-29 08:08:09 b'Submitted batch job 45221410\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed61.sh submitted!
# job id: 45221410
# 62
# 2022-10-29 08:08:10 b'Submitted batch job 45221411\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed62.sh submitted!
# job id: 45221411
# 63
# 2022-10-29 08:08:10 b'Submitted batch job 45221412\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed63.sh submitted!
# job id: 45221412
# 64
# 2022-10-29 08:08:10 b'Submitted batch job 45221413\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed64.sh submitted!
# job id: 45221413
# 65
# 2022-10-29 08:08:10 b'Submitted batch job 45221414\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed65.sh submitted!
# job id: 45221414
# 66
# 2022-10-29 08:08:11 b'Submitted batch job 45221415\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed66.sh submitted!
# job id: 45221415
# 67
# 2022-10-29 08:08:11 b'Submitted batch job 45221416\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed67.sh submitted!
# job id: 45221416
# 68
# 2022-10-29 08:08:11 b'Submitted batch job 45221417\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed68.sh submitted!
# job id: 45221417
# 69
# 2022-10-29 08:08:11 b'Submitted batch job 45221418\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed69.sh submitted!
# job id: 45221418
# 70
# 2022-10-29 08:08:12 b'Submitted batch job 45221419\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed70.sh submitted!
# job id: 45221419
# 71
# 2022-10-29 08:08:12 b'Submitted batch job 45221420\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed71.sh submitted!
# job id: 45221420
# 72
# 2022-10-29 08:08:12 b'Submitted batch job 45221421\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed72.sh submitted!
# job id: 45221421
# 73
# 2022-10-29 08:08:13 b'Submitted batch job 45221422\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed73.sh submitted!
# job id: 45221422
# 74
# 2022-10-29 08:08:13 b'Submitted batch job 45221424\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed74.sh submitted!
# job id: 45221424
# 75
# 2022-10-29 08:08:13 b'Submitted batch job 45221426\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed75.sh submitted!
# job id: 45221426
# 76
# 2022-10-29 08:08:14 b'Submitted batch job 45221428\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed76.sh submitted!
# job id: 45221428
# 77
# 2022-10-29 08:08:14 b'Submitted batch job 45221430\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed77.sh submitted!
# job id: 45221430
# 78
# 2022-10-29 08:08:14 b'Submitted batch job 45221432\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed78.sh submitted!
# job id: 45221432
# 79
# 2022-10-29 08:08:15 b'Submitted batch job 45221433\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed79.sh submitted!
# job id: 45221433
# 80
# 2022-10-29 08:08:15 b'Submitted batch job 45221435\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed80.sh submitted!
# job id: 45221435
# 81
# 2022-10-29 08:08:15 b'Submitted batch job 45221437\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed81.sh submitted!
# job id: 45221437
# 82
# 2022-10-29 08:08:16 b'Submitted batch job 45221439\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed82.sh submitted!
# job id: 45221439
# 83
# 2022-10-29 08:08:16 b'Submitted batch job 45221441\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed83.sh submitted!
# job id: 45221441
# 84
# 2022-10-29 08:08:16 b'Submitted batch job 45221442\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed84.sh submitted!
# job id: 45221442
# 85
# 2022-10-29 08:08:17 b'Submitted batch job 45221444\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed85.sh submitted!
# job id: 45221444
# 86
# 2022-10-29 08:08:17 b'Submitted batch job 45221446\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed86.sh submitted!
# job id: 45221446
# 87
# 2022-10-29 08:08:18 b'Submitted batch job 45221448\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed87.sh submitted!
# job id: 45221448
# 88
# 2022-10-29 08:08:18 b'Submitted batch job 45221450\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed88.sh submitted!
# job id: 45221450
# 89
# 2022-10-29 08:08:18 b'Submitted batch job 45221452\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed89.sh submitted!
# job id: 45221452
# 90
# 2022-10-29 08:08:19 b'Submitted batch job 45221454\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed90.sh submitted!
# job id: 45221454
# 91
# 2022-10-29 08:08:19 b'Submitted batch job 45221455\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed91.sh submitted!
# job id: 45221455
# 92
# 2022-10-29 08:08:19 b'Submitted batch job 45221457\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed92.sh submitted!
# job id: 45221457
# 93
# 2022-10-29 08:08:20 b'Submitted batch job 45221459\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed93.sh submitted!
# job id: 45221459
# 94
# 2022-10-29 08:08:20 b'Submitted batch job 45221461\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed94.sh submitted!
# job id: 45221461
# 95
# 2022-10-29 08:08:20 b'Submitted batch job 45221463\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed95.sh submitted!
# job id: 45221463
# 96
# 2022-10-29 08:08:21 b'Submitted batch job 45221465\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed96.sh submitted!
# job id: 45221465
# 97
# 2022-10-29 08:08:21 b'Submitted batch job 45221466\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed97.sh submitted!
# job id: 45221466
# 98
# 2022-10-29 08:08:22 b'Submitted batch job 45221468\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed98.sh submitted!
# job id: 45221468
# 99
# 2022-10-29 08:08:22 b'Submitted batch job 45221470\n' None
# /pool001/shibal/results-synthetic/bashes/v13_n100_r1.5/seed99.sh submitted!
# job id: 45221470

# %%
from subprocess import Popen, PIPE

# %%
for job in range(45069627, 45069643):
    process = Popen(['scancel',str(job)], stdout=PIPE)
    (output, err) = process.communicate()
    exit_code = process.wait()
    if exit_code ==0:
        print(job, "deleted!")
# Out:
# 45069627 deleted!
# 45069628 deleted!
# 45069629 deleted!
# 45069630 deleted!
# 45069631 deleted!
# 45069632 deleted!
# 45069633 deleted!
# 45069634 deleted!
# 45069635 deleted!
# 45069636 deleted!
# 45069637 deleted!
# 45069638 deleted!
# 45069639 deleted!
# 45069640 deleted!
# 45069641 deleted!
# 45069642 deleted!

# %%
for seed in range(100):
    command = f"""rm -r /pool001/shibal/results-synthetic/N_train_100/seed{seed}/AMsWithInteractionsStrongHierarchy/v12/r1.0"""
    print(command)
    # !{command}
# Out:
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed0/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed1/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed2/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed3/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed4/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed5/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed6/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed7/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed8/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed9/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed10/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed11/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed12/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed13/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed14/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed15/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed16/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed17/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed18/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed19/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed20/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed21/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed22/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed23/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed24/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed25/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed26/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed27/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed28/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed29/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed30/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed31/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed32/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed33/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed34/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed35/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed36/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed37/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed38/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed39/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed40/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed41/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed42/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed43/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed44/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed45/AMsWithInteractionsStrongHierarchy/v12/r1.0
# ^C
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed46/AMsWithInteractionsStrongHierarchy/v12/r1.0
# ^C
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed47/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed48/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed49/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed50/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed51/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed52/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed53/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed54/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed55/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed56/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed57/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed58/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed59/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed60/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed61/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed62/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed63/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed64/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed65/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed66/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed67/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed68/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed69/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed70/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed71/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed72/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed73/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed74/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed75/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed76/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed77/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed78/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed79/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed80/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed81/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed82/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed83/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed84/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed85/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed86/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed87/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed88/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed89/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed90/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed91/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed92/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed93/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed94/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed95/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed96/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed97/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed98/AMsWithInteractionsStrongHierarchy/v12/r1.0
# rm -r /pool001/shibal/results-synthetic/N_train_100/seed99/AMsWithInteractionsStrongHierarchy/v12/r1.0

# %%
import numpy as np

# %%
vals = []
MISE = []
mains = []
interactions = []
fprs_main = []
fnrs_main = []
f1s_main = []
fprs_interaction = []
fnrs_interaction = []
f1s_interaction = []


for seed in np.arange(100):
    filename = '/pool001/shibal/results-synthetic/N_train_1000/seed{}/AMsWithInteractionsStrongHierarchy/v13/r1.5'.format(seed)
    
    try:
        with open(filename+'/Results-HS.txt') as file:
            lines = file.readlines()
            val = float([line for line in lines if "val" in line][0].split("val: ")[1].split(",")[0])
            vals.append(val)
            mise = float([line for line in lines if "True" in line][0].split(" ")[-1].split("\n")[0])
            MISE.append(mise)
            fpr_main = float([line for line in lines if "FPR (main)" in line][0].split(" ")[-1].split("\n")[0])
            fprs_main.append(fpr_main)
            fnr_main = float([line for line in lines if "FNR (main)" in line][0].split(" ")[-1].split("\n")[0])
            fnrs_main.append(fnr_main)
            f1_main = float([line for line in lines if "F1 (main)" in line][0].split(" ")[-1].split("\n")[0])
            f1s_main.append(f1_main)
            fpr_interaction = float([line for line in lines if "FPR (interactions)" in line][0].split(" ")[-1].split("\n")[0])
            fprs_interaction.append(fpr_interaction)
            fnr_interaction = float([line for line in lines if "FNR (interactions)" in line][0].split(" ")[-1].split("\n")[0])
            fnrs_interaction.append(fnr_interaction)
            f1_interaction = float([line for line in lines if "F1 (interactions)" in line][0].split(" ")[-1].split("\n")[0])
            f1s_interaction.append(f1_interaction)
            print("Seed: ", seed, " mise:", mise)
            
        with open(filename+'/support_set.npy', 'rb') as f:
            main_set = np.load(f)
            interaction_set = np.load(f)
            mains.append(main_set)
            interactions.append(interaction_set)
    except:
        print("Seed: ", seed, "Not found")
# Out:
# Seed:  0  mise: 0.011713149340407375
# Seed:  1  mise: 0.020420459946475594
# Seed:  2  mise: 0.010355183527421334
# Seed:  3  mise: 0.014352283879677939
# Seed:  4  mise: 0.008491883886866043
# Seed:  5  mise: 0.008862362145325292
# Seed:  6  mise: 0.015285636911597839
# Seed:  7  mise: 0.011143714250096434
# Seed:  8  mise: 0.015861748580692198
# Seed:  9  mise: 0.016652094427319786
# Seed:  10  mise: 0.01179077518458568
# Seed:  11  mise: 0.017046996364787573
# Seed:  12  mise: 0.010730212903529374
# Seed:  13  mise: 0.013497935493256888
# Seed:  14  mise: 0.01717196980799719
# Seed:  15  mise: 0.011450639709545896
# Seed:  16  mise: 0.017781245815027637
# Seed:  17  mise: 0.022071836166931886
# Seed:  18  mise: 0.01425223400413779
# Seed:  19  mise: 0.011341548644678668
# Seed:  20  mise: 0.010233284218581943
# Seed:  21  mise: 0.014675347370965118
# Seed:  22  mise: 0.013416339923320121
# Seed:  23  mise: 0.011863427939847555
# Seed:  24  mise: 0.015463826706472424
# Seed:  25  mise: 0.013270921005814725
# Seed:  26  mise: 0.009767593739038176
# Seed:  27  mise: 0.010468149601464563
# Seed:  28  mise: 0.01807289851407373
# Seed:  29  mise: 0.011188812705130061
# Seed:  30  mise: 0.021965215861097724
# Seed:  31  mise: 0.012885746707154987
# Seed:  32  mise: 0.014051410528231613
# Seed:  33  mise: 0.021362804346326855
# Seed:  34  mise: 0.01261638187741287
# Seed:  35  mise: 0.01900627078284807
# Seed:  36  mise: 0.015248069145186663
# Seed:  37  mise: 0.008579635694667137
# Seed:  38  mise: 0.011168031921320298
# Seed:  39  mise: 0.013867208300422944
# Seed:  40  mise: 0.012844186685578768
# Seed:  41  mise: 0.009507497358853147
# Seed:  42  mise: 0.011362874829130927
# Seed:  43  mise: 0.020201389641357013
# Seed:  44  mise: 0.012728208453523517
# Seed:  45  mise: 0.010873383990685182
# Seed:  46  mise: 0.016222342768293607
# Seed:  47  mise: 0.015821281431849143
# Seed:  48  mise: 0.017202846475537627
# Seed:  49  mise: 0.01449385868089027
# Seed:  50  mise: 0.015409417729115677
# Seed:  51  mise: 0.011495087426863478
# Seed:  52  mise: 0.014870187446613866
# Seed:  53  mise: 0.01999011096984538
# Seed:  54  mise: 0.016557198618123034
# Seed:  55  mise: 0.011582092158789673
# Seed:  56  mise: 0.013833521823192252
# Seed:  57  mise: 0.012397052625822871
# Seed:  58  mise: 0.007907735693308592
# Seed:  59  mise: 0.018506007939147917
# Seed:  60  mise: 0.00846667226898926
# Seed:  61  mise: 0.0170613086784433
# Seed:  62  mise: 0.014090888981762192
# Seed:  63  mise: 0.013232182473790004
# Seed:  64  mise: 0.00940682318624414
# Seed:  65  mise: 0.017102088638875735
# Seed:  66  mise: 0.016529242081751567
# Seed:  67  mise: 0.01684050117173229
# Seed:  68  mise: 0.009494771980300597
# Seed:  69  mise: 0.017758813579909175
# Seed:  70  mise: 0.00960456598892207
# Seed:  71  mise: 0.018380487345385797
# Seed:  72  mise: 0.012760938707973742
# Seed:  73  mise: 0.009132896760840852
# Seed:  74  mise: 0.009218281510309772
# Seed:  75  mise: 0.012528175425981761
# Seed:  76  mise: 0.011885622355109805
# Seed:  77  mise: 0.012849014571580488
# Seed:  78  mise: 0.019418686767023605
# Seed:  79  mise: 0.011696931723296448
# Seed:  80  mise: 0.008995539060541414
# Seed:  81  mise: 0.008738654536609748
# Seed:  82  mise: 0.015896273950604854
# Seed:  83  mise: 0.0279402766924775
# Seed:  84  mise: 0.013464191482921356
# Seed:  85  mise: 0.019471035801304784
# Seed:  86  mise: 0.020041162221250276
# Seed:  87  mise: 0.013427317899426418
# Seed:  88  mise: 0.00998960604228327
# Seed:  89  mise: 0.013630646192215457
# Seed:  90  mise: 0.01179615616491453
# Seed:  91  mise: 0.007946763211139693
# Seed:  92  mise: 0.017116402951225008
# Seed:  93  mise: 0.010885222318747117
# Seed:  94  mise: 0.014898136481681146
# Seed:  95  mise: 0.009530741027297998
# Seed:  96  mise: 0.01162564542228
# Seed:  97  mise: 0.011639203526551805
# Seed:  98  mise: 0.015194292033507185
# Seed:  99  mise: 0.011425351555001675

# %%
len(MISE)
# Out:
# 100

# %%
np.median(MISE)
# Out:
# 0.013343630464567423

# %%
print("val:", np.mean(vals), "std-err:", np.std(vals)/np.sqrt(len(vals)))
print("MISE:", np.mean(MISE), "std-err:", np.std(MISE)/np.sqrt(len(MISE)))
print("FPR (main):", np.mean(fprs_main), "std-err:", np.std(fprs_main)/np.sqrt(len(fprs_main)))
print("FNR (main):", np.mean(fnrs_main), "std-err:", np.std(fnrs_main)/np.sqrt(len(fnrs_main)))
print("F1 (main):", np.mean(f1s_main), "std-err:", np.std(f1s_main)/np.sqrt(len(f1s_main)))
print("FPR (interactions):", np.mean(fprs_interaction), "std-err:", np.std(fprs_interaction)/np.sqrt(len(fprs_interaction)))
print("FNR (interactions):", np.mean(fnrs_interaction), "std-err:", np.std(fnrs_interaction)/np.sqrt(len(fnrs_interaction)))
print("F1 (interactions):", np.mean(f1s_interaction), "std-err:", np.std(f1s_interaction)/np.sqrt(len(f1s_interaction)))
# Out:
# val: 0.07870474000000001 std-err: 0.00037692249485006855
# MISE: 0.013843630833964615 std-err: 0.0003772733635629191
# FPR (main): 0.0016666666666666663 std-err: 0.0016583123951777
# FNR (main): 0.0 std-err: 0.0
# F1 (main): 0.9988888888888888 std-err: 0.0011055415967851322
# FPR (interactions): 0.0011904761904761919 std-err: 0.0006185895741317425
# FNR (interactions): 0.013333333333333334 std-err: 0.006531972647421809
# F1 (interactions): 0.9852142857142857 std-err: 0.005117252730733951

# %%
np.unique(np.concatenate(mains).ravel(), return_counts=True)
# Out:
# (array([0, 1, 2, 3, 7]), array([100, 100, 100, 100,   1]))

# %%
interactions = [inter for inter in interactions if len(inter)>0]
np.unique(np.concatenate(interactions, axis=0), return_counts=True, axis=0)
# Out:
# (array([[0, 1],
#         [0, 2],
#         [0, 7],
#         [1, 3],
#         [2, 3],
#         [3, 7]]),
#  array([100, 100,   1,   3,  96,   1]))
